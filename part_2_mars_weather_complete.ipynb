# %% [markdown]
# # Module 11 Challenge
# ## Deliverable 2: Scrape and Analyze Mars Weather Data

# %%
# Import relevant libraries
from splinter import Browser
from bs4 import BeautifulSoup as soup
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
browser = Browser('chrome')

# %% [markdown]
# ### Step 1: Visit the Website
#
# Use automated browsing to visit the [Mars Temperature Data Site](https://static.bc-edx.com/data/web/mars_facts/temperature.html). Inspect the page to identify which elements to scrape.
#
#    > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools to discover whether the table contains usable classes.

# %%
# Visit the website
# https://static.bc-edx.com/data/web/mars_facts/temperature.html
url = "https://static.bc-edx.com/data/web/mars_facts/temperature.html"
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Table
#
# Create a Beautiful Soup object and use it to scrape the data in the HTML table.
#
# Note that this can also be achieved by using the Pandas `read_html` function. However, use Beautiful Soup here to continue sharpening your web scraping skills.

# %%
# Create a Beautiful Soup Object
html = browser.html
soup = soup(html, 'html.parser')

# %%
# Extract all rows of data
table = soup.find('table')

# %% [markdown]
# ### Step 3: Store the Data
#
# Assemble the scraped data into a Pandas DataFrame. The columns should have the same headings as the table on the website. Here’s an explanation of the column headings:
#
# * `id`: the identification number of a single transmission from the Curiosity rover
# * `terrestrial_date`: the date on Earth
# * `sol`: the number of elapsed sols (Martian days) since Curiosity landed on Mars
# * `ls`: the solar longitude
# * `month`: the Martian month
# * `min_temp`: the minimum temperature, in Celsius, of a single Martian day (sol)
# * `pressure`: The atmospheric pressure at Curiosity's location

# %%
# Create an empty list
data = []
header = None

# Loop through the scraped data to create a list of rows
for row in table.find_all('tr'):
    columns = row.find_all(['th', 'td'])
    row_data = [col.get_text(strip=True) for col in columns]

    # Use the first row as headers
    if not header:
        header = row_data
    else:
        data.append(row_data)

# %%
# Create a Pandas DataFrame by using the list of rows and a list of the column names
marsweatherscraped_df = pd.DataFrame(data, columns=header)

# %%
# Confirm DataFrame was created successfully
marsweatherscraped_df.head()
# Out:
#    id terrestrial_date sol   ls month min_temp pressure
# 0   2       2012-08-16  10  155     6    -75.0    739.0
# 1  13       2012-08-17  11  156     6    -76.0    740.0
# 2  24       2012-08-18  12  156     6    -76.0    741.0
# 3  35       2012-08-19  13  157     6    -74.0    732.0
# 4  46       2012-08-20  14  157     6    -74.0    740.0

# %% [markdown]
# ### Step 4: Prepare Data for Analysis
#
# Examine the data types that are currently associated with each column. If necessary, cast (or convert) the data to the appropriate `datetime`, `int`, or `float` data types.
#
#   > **Hint** You can use the Pandas `astype` and `to_datetime` methods to accomplish this task.

# %%
# Examine data type of each column
print(marsweatherscraped_df.dtypes)
# Out:
# id                  object
# terrestrial_date    object
# sol                 object
# ls                  object
# month               object
# min_temp            object
# pressure            object
# dtype: object

# %%
# Change data types for data analysis
marsweatherscraped_df['terrestrial_date'] = pd.to_datetime(marsweatherscraped_df['terrestrial_date'])
marsweatherscraped_df['sol'] = marsweatherscraped_df['sol'].astype(int)
marsweatherscraped_df['ls'] = marsweatherscraped_df['ls'].astype(int)
marsweatherscraped_df['month'] = marsweatherscraped_df['month'].astype(int)
marsweatherscraped_df['min_temp'] = marsweatherscraped_df['min_temp'].astype(float)
marsweatherscraped_df['pressure'] = marsweatherscraped_df['pressure'].astype(float)

# %%
# Confirm type changes were successful by examining data types again
print(marsweatherscraped_df.dtypes)
# Out:
# id                          object
# terrestrial_date    datetime64[ns]
# sol                          int32
# ls                           int32
# month                        int32
# min_temp                   float64
# pressure                   float64
# dtype: object

# %% [markdown]
# ### Step 5: Analyze the Data
#
# Analyze your dataset by using Pandas functions to answer the following questions:
#
# 1. How many months exist on Mars?
# 2. How many Martian (and not Earth) days worth of data exist in the scraped dataset?
# 3. What are the coldest and the warmest months on Mars (at the location of Curiosity)? To answer this question:
#     * Find the average the minimum daily temperature for all of the months.
#     * Plot the results as a bar chart.
# 4. Which months have the lowest and the highest atmospheric pressure on Mars? To answer this question:
#     * Find the average the daily atmospheric pressure of all the months.
#     * Plot the results as a bar chart.
# 5. About how many terrestrial (Earth) days exist in a Martian year? To answer this question:
#     * Consider how many days elapse on Earth in the time that Mars circles the Sun once.
#     * Visually estimate the result by plotting the daily minimum temperature.

# %%
# 1. How many months are there on Mars?

# Count the frequency of values in the 'month' column
month_counts = marsweatherscraped_df['month'].value_counts().sort_index()

# Display the result
month_counts
# Out:
# month
# 1     174
# 2     178
# 3     192
# 4     194
# 5     149
# 6     147
# 7     142
# 8     141
# 9     134
# 10    112
# 11    138
# 12    166
# Name: count, dtype: int64

# %%
# 2. How many Martian days' worth of data are there?

# Count the total number of unique values in the 'terrestrial_date' column
total_unique_dates = marsweatherscraped_df['sol'].nunique()

# Display the result
total_unique_dates
# Out:
# 1867

# %%
# 3. What is the average low temperature by month?

# Group by 'month' and calculate the mean of 'min_temp' for each group
mean_min_temp_by_month = marsweatherscraped_df.groupby('month')['min_temp'].mean()

# Display the result
mean_min_temp_by_month
# Out:
# month
# 1    -77.160920
# 2    -79.932584
# 3    -83.307292
# 4    -82.747423
# 5    -79.308725
# 6    -75.299320
# 7    -72.281690
# 8    -68.382979
# 9    -69.171642
# 10   -71.982143
# 11   -71.985507
# 12   -74.451807
# Name: min_temp, dtype: float64

# %%
# Plot the average temperature by month

# Plot the bar chart
mean_min_temp_by_month.plot(kind='bar')

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Mean Minimum Temperature (Degrees Celcius)')
plt.title('Average Temperature per Month on Mars')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Identify the coldest and hottest months in Curiosity's location

# Sort the DataFrame by mean min_temp and reset the index
mean_min_temp_by_month_sorted = mean_min_temp_by_month.sort_values()
mean_min_temp_by_month_sorted = mean_min_temp_by_month_sorted.reset_index()

# Plot the bar chart
mean_min_temp_by_month_sorted.set_index('month')['min_temp'].sort_values().plot(kind='bar')

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Mean Minimum Temperature (Degrees Celcius)')
plt.title('Average Temperature per Month on Mars')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# 4. Average pressure by Martian month

# Group by 'month' and calculate the mean of 'pressure' for each group
mean_pressure_by_month = marsweatherscraped_df.groupby('month')['pressure'].mean()

# Display the result
mean_pressure_by_month
# Out:
# month
# 1     862.488506
# 2     889.455056
# 3     877.322917
# 4     806.329897
# 5     748.557047
# 6     745.054422
# 7     795.105634
# 8     873.829787
# 9     913.305970
# 10    887.312500
# 11    857.014493
# 12    842.156627
# Name: pressure, dtype: float64

# %%
# Plot the average pressure by month

# Sort the DataFrame by mean min_temp and reset the index
mean_pressure_by_month_sorted = mean_pressure_by_month.sort_values()
mean_pressure_by_month_sorted = mean_pressure_by_month_sorted.reset_index()

# Plot the bar chart
mean_pressure_by_month_sorted.set_index('month')['pressure'].sort_values().plot(kind='bar')

# Set labels and title
plt.xlabel('Month')
plt.ylabel('Mean Pressure')
plt.title('Average Pressure per Month on Mars')

# Show the plot
plt.tight_layout()
plt.show()

# %%
# 5. How many terrestrial (earth) days are there in a Martian year?

# Calculate the number of days relative to the first row
marsweatherscraped_df['days'] = (marsweatherscraped_df['terrestrial_date'] - marsweatherscraped_df['terrestrial_date'].iloc[0]).dt.days

# Plotting the scatter plot
marsweatherscraped_df.plot(x='days', y='min_temp', kind='line', title='Scatter Plot of Number of Earth Days vs Min Temperature', legend=False)
plt.xlabel('Number of Earth Days')
plt.ylabel('Min Temperature (Degrees Celcius')
plt.title('Scatter Plot of Number of Earth Days vs Min Temperature')
plt.show()

# %% [markdown]
# On average, the third month has the coldest minimum temperature on Mars, and the eighth month is the warmest. But it is always very cold there in human terms!

# %% [markdown]
# Atmospheric pressure is, on average, lowest in the sixth month and highest in the ninth.

# %% [markdown]
# ##### The distance from trough to trough is roughly 1250-550, or 700 days. A year on Mars appears to be about 700 days from the plot. Internet search confirms that a Mars year is equivalent to 687 earth days.

# %% [markdown]
# ### Step 6: Save the Data
#
# Export the DataFrame to a CSV file.

# %%
# Write the data to a CSV
# Get the current working directory
cwd = os.getcwd()

# Create the 'output' subdirectory if it doesn't exist
output_dir = os.path.join(cwd, 'output')
os.makedirs(output_dir, exist_ok=True)

# Save the DataFrame to a CSV file in the 'output' directory
output_csv_path = os.path.join(output_dir, 'marsweather.csv')
marsweatherscraped_df.to_csv(output_csv_path, index=False)

# %%
browser.quit()
